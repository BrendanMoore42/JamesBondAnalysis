# %% [markdown]
# Looking at the sentiment values for every james bond movie. OH baby.
#
# Checks overall sentiment over time in each movie holy shit great idea.
#
# Set srt file to dataframe, analyse dataframe.

# %%
# import subprocess

# subprocess.run(["subliminal", "download","-l ", "en", "Dr_No.mp4"])

# %%
import re 
import os
import sys
import glob
import time
import selenium
import numpy as np
import pandas as pd
from PIL import Image

from babelfish import *
from subliminal import *

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from collections import Counter
from wordcloud import WordCloud, STOPWORDS


#disable chained warnings
pd.options.mode.chained_assignment = None

# %%
# get bond film table
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_James_Bond_films')
# get movie titles
jb_movies = df[0][2:-2][0].values
jb_flicks = []

for j in jb_movies:
#     j = j.replace("[N]", '')
#     video = Video.fromname(f'{j}')
#     subtitle = list_subtitles([video], {Language('eng')})
#     subtitle = subtitle[video][0]
#     download_subtitles([subtitle])
#     save_subtitles(video, [subtitle], directory='Subtitles')
    pass

# %%
df_titles = df[0][0:1].values
df_main = pd.DataFrame(df[0][2:-2])
df_main.columns = df_titles[0]

# clean columns
df_main['Title'] = df_main.Title.apply(lambda x: x.replace('[N]', ''))
df_main.drop(df_main.index[4], inplace=True)

# Sort by decade
df_main['Decade'] = df_main['Year'].apply(lambda x: x[2]+'0')

df_main.reset_index(drop=True, inplace=True)
df_main
# Out:
#                               Title  Year      Bond actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 5   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 6              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 7                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 8       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 9              The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 10                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 11               For Your Eyes Only  1981     Roger Moore           John Glen
# 12                        Octopussy  1983     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                 A View to a Kill  1985     Roger Moore           John Glen
# 15             The Living Daylights  1987  Timothy Dalton           John Glen
# 16                  Licence to Kill  1989  Timothy Dalton           John Glen
# 17                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 18              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 19          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 20                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 21                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 22                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 23                          Skyfall  2012    Daniel Craig          Sam Mendes
# 24                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box office                   Budget               Salary of Bond actor  \
# 0         59.5                      1.1                             0.1[b]
# 1         78.9                      2.0                                0.3
# 2        124.9                      3.0                                0.5
# 3        141.2                      6.8                                0.8
# 4        101.0                     10.3  0.8 + 25% net merchandise royalty
# 5         64.6                      7.0                                0.1
# 6        116.0                      7.2    1.2 + 12.5% of gross (14.5) [c]
# 7        126.4                      7.0                               0.18
# 8         98.5                      7.0                        0.24 + 2.5%
# 9        185.4                     14.0                        0.3 + 3.75%
# 10       210.3                     34.0                                NaN
# 11       194.9                     28.0                                NaN
# 12       183.7                     27.5                                4.0
# 13     160[21]                   36[21]                                NaN
# 14       152.4                     30.0                                5.0
# 15       191.2                     40.0                                3.0
# 16       156.2                     36.0                                5.0
# 17       351.9                     60.0                                4.0
# 18       338.9                    110.0                                8.2
# 19       361.8                    135.0                               12.4
# 20       431.9                    142.0                               16.5
# 21       594.2                    150.0                                3.4
# 22       576.0                    200.0                                8.9
# 23  1108.6[23]  150.0[24][25]–200.0[23]                           17.0[26]
# 24   880.7[27]           245.0–250.0[d]                             39[35]
#
#    Box office           Budget                Salary of Bond actor Decade
# 0       448.8              7.0                                 0.6     60
# 1       543.8             12.6                                 1.6     60
# 2       820.4             18.6                                 3.2     60
# 3       848.1             41.9                                 4.7     60
# 4       514.2             59.9  4.4 excluding profit participation     60
# 5       291.5             37.3                                 0.6     60
# 6       442.5             34.7  5.8 excluding profit participation     70
# 7       460.3             30.8                                 0.7     70
# 8       334.0             27.7  0.8 excluding profit participation     70
# 9       533.0             45.1  0.9 excluding profit participation     70
# 10      535.0             91.5                                 NaN     70
# 11      449.4             60.2                                 NaN     80
# 12      373.8             53.9                                 7.8     80
# 13    314[22]           71[22]                                 NaN     80
# 14      275.2             54.5                                 9.1     80
# 15      313.5             68.8                                 5.2     80
# 16      250.9             56.7                                 7.9     80
# 17      518.5             76.9                                 5.1     90
# 18      463.2            133.9                                10.0     90
# 19      439.5            158.3                                13.5     90
# 20      465.4            154.2                                17.9     00
# 21      581.5            145.3                                 3.3     00
# 22      514.2            181.4                                 8.1     00
# 23  943.5[22]  127.7–170.2[22]                            14.5[22]     10
# 24  725.5[22]  201.8–205.9[22]                            32.1[22]     10

# %%
# the following check and clean srt specific lines
def is_time_stamp(l):
    if l[:2].isnumeric() and l[2] == ':':
        return True
    return False

def get_start_time(line):
    time = line.split()[0]
    print(time)
    if time[:2].isnumeric() and time[2] == ':':
        print(time)


def has_letters(line):
    if re.search('[a-zA-Z]', line):
        return True
    return False


def has_no_text(line):
    l = line.strip()
    if not len(l):
        return True
    if l.isnumeric():
        return True
    if is_time_stamp(l):
        return True
    if l[0] == '(' and l[-1] == ')':
        return True
    if not has_letters(line):
        return True
    return False


def is_lowercase_letter_or_comma(letter):
    if letter.isalpha() and letter.lower() == letter:
        return True
    if letter == ',':
        return True
    return False

# removes non-text lines, combines broken lines
def clean_up(lines):
    # add 'text' to list so the dataframe has a column name
    new_lines = []
    time_stamps = []
    temp_lst = []
    for line in lines[1:]:
        if has_no_text(line):
            if line[:2].isnumeric() and line[2] == ':':
                time_stamps.append(line[:8])
                continue
            continue
        elif len(new_lines) and is_lowercase_letter_or_comma(line[0]):
            #combine with previous line
            new_lines[-1] = new_lines[-1].strip() + ' ' + line
        else:
            #append line
            new_lines.append(line)
    for text, time in zip(new_lines, time_stamps):
        temp_line = [time, text.replace('\n', '').replace('-', '')]
        temp_lst.append(temp_line)
    return temp_lst


# convert srt to txt file from directory returns dict
def srt_to_txt(srt_file, encoding):
    with open(srt_file, encoding=encoding, errors='replace') as f:
        lines = f.readlines()
        new_lines = clean_up(lines)
    new_file_name = srt_file[:-4] + '.txt'
    return new_lines

# puts .txt file into a dataframe, returns df
def to_df(text):
    df = pd.read_csv(pd.compat.StringIO("\n".join(text)), sep=";")
    #remove puncutation
    df['text'] = df['text'].str.replace('[^\w\s]', '')
    return df

va = SentimentIntensityAnalyzer()
def get_sentiment(tweet):
    """
    VADER Analysis --> returns negative, neutral, positive, compounded sentiment.
    compound = normalized, weighted composite score between -1, 1
    """
    score = va.polarity_scores(tweet)
    temp_list = [score['compound'], score['pos'], score['neu'], score['neg']]
    return temp_list[0]

# %%
srt_test = 'Subtitles/GoldenEye.en.srt'
encoding = 'utf-8' 
temp_srt = srt_to_txt(srt_test, encoding)[1:] #ignore first advertisement 
temp_srt
# Out:
# [['00:02:58', 'I beg your pardon.'],
#  ['00:03:46', 'I forgot to knock.'],
#  ['00:03:51', "I'm alone."],
#  ['00:03:54', "Aren't we all?"],
#  ['00:03:57', " You're late, 007."],
#  ['00:03:59', ' I had to stop in the bathroom.'],
#  ['00:04:05', 'Ready to save the world again?'],
#  ['00:04:09', 'After you, 006.'],
#  ['00:04:52', 'James, for England.'],
#  ['00:04:54', 'For England, Alec.'],
#  ['00:04:57', "It's too easy."],
#  ['00:05:00', 'Half of everything is luck, James.'],
#  ['00:05:03', 'And the other half?'],
#  ['00:05:32', 'Fate.'],
#  ['00:05:36', ' Set timers: six minutes.'],
#  ['00:05:39', ' Six minutes, check.'],
#  ['00:05:56', 'Fire!'],
#  ['00:06:00', 'Closing time, James!'],
#  ['00:06:05', 'Last call!'],
#  ['00:06:10', 'Buy me a pint.'],
#  ['00:06:24',
#   'This is Colonel Ourumov! Come out with your hands above your heads!'],
#  ['00:06:28', 'How original.'],
#  ['00:06:30', 'Shut the door, Alec!'],
#  ['00:06:34', "There's a draft!"],
#  ['00:06:36', 'Alec?'],
#  ['00:06:39', 'Move out. Throw down your weapon and walk towards me, slowly.'],
#  ['00:06:43', 'Finish the job, James!'],
#  ['00:06:44', 'Blow them all to hell!'],
#  ['00:06:47', 'You have ten seconds.'],
#  ['00:06:50',
#   'Ten... nine... eight... seven... six... five... four... three... two...'],
#  ['00:06:56', 'For England, James!'],
#  ['00:07:03', 'Hold your fire!'],
#  ['00:07:44', "You'll blow the gas tanks!"],
#  ['00:08:05', 'This is your last chance.'],
#  ['00:08:22', 'Come out with your hands above your...'],
#  ['00:08:58', 'Wait!'],
#  ['00:13:05', "You can't win."],
#  ['00:13:09', 'Get out there! Move!'],
#  ['00:13:20', 'Move it!'],
#  ['00:13:27', 'Hold your fire!'],
#  ['00:14:32', 'Wait!'],
#  ['00:14:36', 'James, is it really necessary to drive quite so fast?'],
#  ['00:14:38', "More often than you'd think."],
#  ['00:14:41', 'I enjoy a spirited ride as much as the next girl, but...'],
#  ['00:14:44', " Who's that?"],
#  ['00:14:47', ' The next girl.'],
#  ['00:14:49', 'James, stop this! Stop it!'],
#  ['00:15:25', "I know what you're doing."],
#  ['00:15:43', 'Really?'],
#  ['00:15:45', "What's that, dear?"],
#  ['00:15:54', 'You are just trying to show off the size of your, your...'],
#  ['00:16:04', ' Engine?'],
#  ['00:16:07', ' Ego.'],
#  ['00:16:10',
#   "We're having a pleasant drive, and you've got to bring psychology into it."],
#  ['00:16:18', 'I was just sent here to evaluate you.'],
#  ['00:17:13', "Let's try and put that behind us, shall we?"],
#  ['00:17:22', 'Ladies first.'],
#  ['00:17:25', ' James, I want you to stop this car.'],
#  ['00:17:27', ' Really?'],
#  ['00:17:30', 'Stop this car at once!'],
#  ['00:17:46', 'As you can see, I have no problem with female authority.'],
#  ['00:17:51', "James, you're incorrigible."],
#  ['00:17:53', 'What am I going to do with you?'],
#  ['00:18:01', "Well, let's toast your evaluation, shall we?"],
#  ['00:18:04', 'A very thorough evaluation.'],
#  ['00:18:07', 'Madame wins.'],
#  ['00:18:46', 'Bet, Mademoiselle? No?'],
#  ['00:18:51', 'Monsieur?'],
#  ['00:18:56', 'Bets, ladies and gentlemen?'],
#  ['00:18:58', 'No players?'],
#  ['00:19:06', 'It appears we share the same passions.'],
#  ['00:19:10', 'Three, anyway.'],
#  ['00:19:12', 'I count two.'],
#  ['00:19:17', 'Motoring and baccarat.'],
#  ['00:19:20', 'Seven. Madame wins.'],
#  ['00:19:22', 'I hope the third is where your real talent lies.'],
#  ['00:19:24', 'One rises to meet a challenge.'],
#  ['00:19:27', 'Madame stands with five.'],
#  ['00:19:32', 'Six. Madame loses.'],
#  ['00:19:34', 'Enjoy it while it lasts.'],
#  ['00:19:37', 'The very words I live by.'],
#  ['00:19:41', 'And what words do you live by?'],
#  ['00:19:45', "The trick is to quit while you're still ahead."],
#  ['00:19:47', "That's one trick I've never learned."],
#  ['00:19:49', "Perhaps you'll show me how it's done."],
#  ['00:19:51', 'Vodka martini.'],
#  ['00:19:54', 'Shaken, not stirred.'],
#  ['00:19:59', 'And for you?'],
#  ['00:20:02', 'The same.'],
#  ['00:20:05', 'How do you take it?'],
#  ['00:20:06', 'Straight up, with a twist.'],
#  ['00:20:10', 'Thank you, Mr... .?'],
#  ['00:20:14', "The name's Bond."],
#  ['00:20:17', 'James Bond.'],
#  ['00:20:20', 'Xenia Zaragevna Onatopp.'],
#  ['00:20:22', ' Onatopp?'],
#  ['00:20:27', ' Onatopp.'],
#  ['00:20:30', 'Your accent, Georgian?'],
#  ['00:20:33', 'Very good, Mr. Bond.'],
#  ['00:22:00', " You've been to Russia?"],
#  ['00:22:02', ' Not recently.'],
#  ['00:22:06', 'I used to drop in occasionally.'],
#  ['00:22:10', 'Shoot in and out.'],
#  ['00:22:13', "It's very different now, a land of opportunity."],
#  ['00:22:16', 'With a new Ferrari in every garage?'],
#  ['00:22:21', 'No, not quite.'],
#  ['00:22:24', 'That belongs to a friend.'],
#  ['00:23:08', 'A tip for your friend:'],
#  ['00:23:20',
#   "The French registration plates for this year's model start with the letter 'L. '"],
#  ['00:24:27', 'Even the counterfeit ones.'],
#  ['00:24:32',
#   'Oh. And what rank do you hold... with the Motor Vehicles Department,'],
#  ['00:24:36', 'Mr. Bond?'],
#  ['00:24:39', 'Commander.'],
#  ['00:25:15', ' Shall we go?'],
#  ['00:25:17', ' This one is an Admiral.'],
#  ['00:25:19', 'I like a woman who enjoys pulling rank.'],
#  ['00:25:23', 'Nice to meet you, Mr. Bond.'],
#  ['00:25:27', "The pleasure, I'm sure, was all mine."],
#  ['00:25:29', 'Transmission begins from Moneypenny.'],
#  ['00:25:31', 'Identification confirmed:'],
#  ['00:25:43', 'Onatopp, Xenia. ExSoviet fighter pilot.'],
#  ['00:25:46', 'Current suspected links to the'],
#  ['00:25:48', 'Janus crime syndicate, St. Petersburg.'],
#  ['00:25:58', 'Yacht Manticore is leased to a known Janus corporate front.'],
#  ['00:26:03',
#   'M authorizes you to observe Miss Onatopp... but stipulates no contact without prior approval.'],
#  ['00:26:05', 'End transmission. Moneypenny.'],
#  ['00:27:12', 'Good night, James.'],
#  ['00:27:14', "I trust you'll stay"],
#  ['00:27:19', "'onatopp' of things."],
#  ['00:27:30', "Xenia, I can't breathe!"],
#  ['00:27:34', 'Yes! Yes!'],
#  ['00:27:40', 'My respects, Admiral.'],
#  ['00:27:43', 'Delighted to have you aboard,'],
#  ['00:27:48', 'Mademoiselle.'],
#  ['00:27:50',
#   'Ladies and gentlemen... please take your seats on the upper deck for the demonstration of the aircraft.'],
#  ['00:27:54',
#   "What you are about to see in operation... is Europe's answer to the electronic battlefield: the first working prototype of the Tiger helicopter."],
#  ['00:27:58',
#   'Uniquely maneuverable, the Tiger not only uses stealth technology... it is the only helicopter to be hardened against... all forms of electronic interference... radio jamming and electromagnetic radiation.'],
#  ['00:28:01',
#   'I have a small surprise from your friends back at the barracks.'],
#  ['00:28:08', "I think I've gone to heaven."],
#  ['00:28:11', 'Not yet.'],
#  ['00:28:19', 'Now please welcome the pilots.'],
#  ['00:28:21', 'Lieutenant Commander'],
#  ['00:28:24', 'Bernard Jaubert... and Lieutenant Francois Brouse.'],
#  ['00:28:27', 'Select Mir.'],
#  ['00:28:33', 'Autographic projection.'],
#  ['00:28:34', 'Compute possible intercept with second stage geosat two.'],
#  ['00:28:41', 'Anna.'],
#  ['00:28:47', "He wouldn't know a woman if one came up and sat on his head."],
#  ['00:28:48', 'Boris.'],
#  ['00:28:50', ' Boris!'],
#  ['00:28:55', ' What?'],
#  ['00:28:57', "I thought I'd post it on the Internet, no?"],
#  ['00:28:59', " What's the password?"],
#  ['00:29:02', ' I made it easy this time.'],
#  ['00:29:05', 'Even you should be able to break it, borscht for brains.'],
#  ['00:29:13', 'All right, all right,'],
#  ['00:29:16', "I'll give you a hint."],
#  ['00:29:20', "They're right in front of you and can open very large doors."],
#  ['00:29:27', "You're such a geek."],
#  ['00:29:30', "Yes, I'm in!"],
#  ['00:29:32', "You've hacked into the U.S. Department of Justice."],
#  ['00:29:34', 'Do you know what will happen if they trace it here?'],
#  ['00:29:41',
#   'The Chief of Computers will call me a genius... move me to Moscow and give me a million bucks hard currency.'],
#  ['00:29:44', 'I think not.'],
#  ['00:29:46', 'Besides, the Americans are slugheads.'],
#  ['00:30:50', "They'll never detect me."],
#  ['00:30:53', ' You were saying, slughead?'],
#  ['00:31:06', ' Nobody screws with Boris Grishenko!'],
#  ['00:31:08', 'Spiked them!'],
#  ['00:31:12', 'Come on, Boris, just hang up.'],
#  ['00:31:16', 'No way! I spiked them!'],
#  ['00:31:18', "All right, what's the password?"],
#  ['00:31:21', "I'm not going to tell you."],
#  ['00:31:25', 'Okay, let me guess.'],
#  ['00:31:30', "It's not in front of me?"],
#  ['00:32:02', "You sit on it, but you can't take it with you."],
#  ['00:32:40',
#   "My program seizes the phone line of whoever's tracing me... and jams their modem so they can't hang up."],
#  ['00:32:42', 'Now the hunted becomes the hunter.'],
#  ['00:32:53', 'Better luck next time... slugheads!'],
#  ['00:33:06', 'Bang! Gone!'],
#  ['00:33:32', 'I am invincible!'],
#  ['00:33:45', 'Was it good for you, too?'],
#  ['00:34:22', "I'm getting some coffee."],
#  ['00:35:00', "I'm going for a cigarette."],
#  ['00:35:03', 'General Arkady Grigorovich Ourumov... head of Space Division.'],
#  ['00:35:06', " General, if I'd known..."],
#  ['00:35:09', " You'd have been ready."],
#  ['00:35:12', 'This is an unscheduled test of the'],
#  ['00:35:13', 'Severnaya facility. War simulation.'],
#  ['00:35:16', 'We are going to testfire GoldenEye.'],
#  ['00:35:20', 'Report your status.'],
#  ['00:35:23', 'Two operational satellites, sir:'],
#  ['00:35:26',
#   'Petya and Mischa... both in 90minute earth orbit at 100 kilometers.'],
#  ['00:35:29', 'Good. Here is the authorization code.'],
#  ['00:35:31',
#   "Now, the GoldenEye and today's access numbers for satellite Petya, please."],
#  ['00:35:38', 'I am timing you.'],
#  ['00:35:41', 'Good.'],
#  ['00:35:44', 'Thank you, Major.'],
#  ['00:35:48', 'On my count.'],
#  ['00:35:54', 'Three... two... one.'],
#  ['00:35:58', 'Set target: Severnaya.'],
#  ['00:36:04', 'Arm the weapon.'],
#  ['00:36:07', 'Check it!'],
#  ['00:36:07', 'Their best response time is 19 minutes.'],
#  ['00:36:09', "They'll be late."],
#  ['00:36:12', "It's clean."],
#  ['00:36:17', 'I had to ventilate someone.'],
#  ['00:36:20', ' Good evening, Moneypenny.'],
#  ['00:36:22', ' Good evening, James.'],
#  ['00:36:24', 'M will meet you in the situation room.'],
#  ['00:36:31', "I'm to take you straight in."],
#  ['00:36:34', "I've never seen you after hours,"],
#  ['00:36:40', 'Moneypenny. Lovely.'],
#  ['00:36:42', ' Thank you, James.'],
#  ['00:36:45', ' Out on a professional assignment?'],
#  ['00:36:48', 'Dressing to kill?'],
#  ['00:36:51',
#   "I know you'll find this crushing, 007... but I don't sit at home every night praying for an international incident... so I can run down here all dressed up to impress James Bond."],
#  ['00:36:54', 'I was on a date with a gentleman.'],
#  ['00:36:57', 'We went to the theater together.'],
#  ['00:37:00', "Moneypenny, I'm devastated."],
#  ['00:37:02', 'What would I ever do without you?'],
#  ['00:37:06', "As far as I can remember, James, you've never had me."],
#  ['00:37:08', 'Hope springs eternal.'],
#  ['00:37:10',
#   'You know, this sort of behavior could qualify as sexual harassment.'],
#  ['00:37:14', 'Really?'],
#  ['00:37:17', "What's the penalty for that?"],
#  ['00:37:42', 'Someday you have to make good on your innuendos.'],
#  ['00:38:46', ' After you, Moneypenny.'],
#  ['00:40:11', ' No, I insist.'],
#  ['00:40:16', 'You first.'],
#  ['00:41:28', ' Good evening, 007.'],
#  ['00:41:30', " Tanner. What's up?"],
#  ['00:41:32', 'Sixteen minutes ago, we intercepted a distress call...'],
#  ['00:41:33',
#   'Sixteen minutes ago, we intercepted a distress call... from a supposedly abandoned radar station at Severnaya.'],
#  ['00:41:35', 'Look what the satellite picked up.'],
#  ['00:41:39', 'We found a match: your missing Tiger.'],
#  ['00:41:43', 'In the middle of Northern Russia.'],
#  ['00:41:47', 'It seems your hunch was right, 007.'],
#  ['00:41:50',
#   "It's too bad the evil Queen of Numbers wouldn't let you play it."],
#  ['00:41:52', ' You were saying?'],
#  ['00:41:55', ' No, I was just...'],
#  ['00:41:57', 'Good. Because if I want sarcasm,'],
#  ['00:41:58', "Mr. Tanner, I'll talk to my children."],
#  ['00:42:02', ' Good evening, 007.'],
#  ['00:42:04', ' Good evening, M.'],
#  ['00:42:06', "The Prime Minister's waiting for an update."],
#  ['00:42:08', 'Proceed with your briefing,'],
#  ['00:42:11', 'Mr. Tanner.'],
#  ['00:42:13', 'Thank you.'],
#  ['00:42:17',
#   'After the distress signal, your helicopter took off... and the Russians scrambled these three MIGs here to intercept it.'],
#  ['00:42:20', 'What do you think the Russians are using the base for?'],
#  ['00:42:21', 'Well, at one point we suspected'],
#  ['00:42:24',
#   'Severnaya might be the ground station... for a secret spacebased weapons program called GoldenEye, but...'],
#  ['00:42:27',
#   'Our statistical analysis saw they had... neither the finance nor technology to implement it.'],
#  ['00:42:31', 'Numbers were never my strong suit.'],
#  ['00:42:34', 'Are these pictures live?'],
#  ['00:42:35',
#   'Unlike the American government, we prefer not to get our bad news from CNN.'],
#  ['00:42:38', 'Negative so far.'],
#  ['00:42:39', 'Everything seems normal.'],
#  ['00:42:42', 'What the bloody hell was that?'],
#  ['00:42:46', 'Natalya Fyodorovna Simonova.'],
#  ['00:42:48', 'Natalya Fyodorovna Simonova!'],
#  ['00:42:51', 'Boris!'],
#  ['00:42:54', 'Boris!'],
#  ['00:42:56', 'Thanks.'],
#  ['00:43:05', 'Our satellite is knocked out.'],
#  ['00:43:15', 'So are two of the Americans.'],
#  ['00:43:38', 'We have another coming into range... now.'],
#  ['00:43:43', 'Good God.'],
#  ['00:43:45', 'Two of the MIGs are down.'],
#  ['00:43:48', 'And it looks like the third went into the dish.'],
#  ['00:43:51', 'What do you think?'],
#  ['00:43:53', 'No lights.'],
#  ['00:43:56', 'Not one single electric light on in a 30mile radius.'],
#  ['00:44:00', 'E.M.P.?'],
#  ['00:44:03', ' That explains the MIGs and satellites.'],
#  ['00:44:06', ' And the blackout.'],
#  ['00:44:08',
#   'Electromagnetic Pulse: a firststrike satellite weapon developed by the...'],
#  ['00:44:12', 'The Americans and Soviets during the Cold War.'],
#  ['00:44:16', "I've read the brief."],
#  ['00:44:26', 'Discovered after Hiroshima.'],
#  ['00:44:28', 'Set off a nuclear device in the upper atmosphere.'],
#  ['00:44:31',
#   'Creates a pulse... a radiation surge that destroys everything with an electronic circuit.'],
#  ['00:44:37',
#   "The idea being to knock out the enemy's communications... before he, she, or they could retaliate."],
#  ['00:44:39', 'So, GoldenEye exists.'],
#  ['00:44:41', 'Yes.'],
#  ['00:44:44', ' Could this be an accident?'],
#  ['00:44:47', ' No.'],
#  ['00:44:51', 'The helicopter.'],
#  ['00:44:54',
#   'If you wanted to steal the GoldenEye, it was the perfect getaway vehicle.'],
#  ['00:44:57',
#   'Setting off the blast was the ideal way to wipe out any trace of the crime.'],
#  ['00:45:00', 'The Janus group?'],
#  ['00:45:02', 'It may have been involved with the helicopter.'],
#  ['00:45:05', 'I know the Russian failsafe systems.'],
#  ['00:45:07', "You don't just walk in and ask for the keys to the bomb."],
#  ['00:45:11', 'You need the access codes.'],
#  ['00:45:13', 'It had to be an insider.'],
#  ['00:45:16', 'And at least one person probably knows who it is.'],
#  ['00:45:18', 'Very well, sir.'],
#  ['00:45:21', 'Thank you. Good night.'],
#  ['00:45:25', "The Prime Minister's talked to Moscow."],
#  ['00:45:27',
#   "They're saying it was an accident during a routine training exercise."],
#  ['00:45:30', 'Governments change.'],
#  ['00:45:38', 'The lies stay the same.'],
#  ['00:45:40', 'What else do we know about the Janus syndicate?'],
#  ['00:45:44', 'Topflight arms dealers, headquartered in St. Petersburg.'],
#  ['00:45:46', 'The first outfit to restock the Iraqis during the Gulf War.'],
#  ['00:45:49', "The head man's unreliably described."],
#  ['00:45:51', 'No photographs.'],
#  ['00:45:54', 'The woman, Onatopp... is our only confirmed contact.'],
#  ['00:45:57', ' Would you care for a drink?'],
#  ['00:46:01', ' Thank you.'],
#  ['00:46:06', ' Your predecessor kept cognac in the...'],
#  ['00:46:47', ' I prefer bourbon.'],
#  ['00:46:51', ' Ice?'],
#  ['00:46:54', ' Yes.'],
#  ['00:46:59',
#   "We've pulled the files on anyone who might have had access... or authority at Severnaya."],
#  ['00:47:02',
#   'The top name on the list is an old friend of yours, I understand.'],
#  ['00:47:06', 'Ourumov.'],
#  ['00:47:08', 'They made him a General.'],
#  ['00:47:11', 'He sees himself as the next Iron Man of Russia.'],
#  ['00:47:15', 'So our political analysts rule him out.'],
#  ['00:47:19', "He doesn't fit the profile of a traitor."],
#  ['00:47:21',
#   "Are these the same analysts who said that GoldenEye couldn't exist?"],
#  ['00:47:23',
#   "Who said the helicopter posed no immediate threat... and wasn't worth following?"],
#  ['00:47:26', "You don't like me, Bond."],
#  ['00:47:31', "You don't like my methods."],
#  ['00:47:34',
#   "You think I'm an accountant... a 'bean counter, ' more interested in my numbers than your instincts."],
#  ['00:47:38', ' The thought had occurred to me.'],
#  ['00:47:40', ' Good.'],
#  ['00:47:46', "Because I think you're a sexist, misogynist dinosaur."],
#  ['00:47:50',
#   'A relic of the Cold War... whose boyish charms, though wasted on me, obviously appeal... to that young woman'],
#  ['00:47:53', 'I sent out to evaluate you.'],
#  ['00:47:56', ' Point taken.'],
#  ['00:47:59', ' Not quite, 007.'],
#  ['00:48:01',
#   "If you think for one moment I don't have the balls to send a man out to die... your instincts are dead wrong."],
#  ['00:48:04', "I've no compunction about sending you to your death."],
#  ['00:48:08',
#   "But I won't do it on a whim, even with your cavalier attitude towards life."],
#  ['00:48:10', 'I want you to find GoldenEye.'],
#  ['00:48:13', 'Find who took it, what they plan to do with it, and stop it.'],
#  ['00:48:17', 'And if you should come across Ourumov, guilty or not...'],
#  ['00:48:32', "I don't want you running off on some kind of vendetta."],
#  ['00:48:38', 'Avenging Alec Trevelyan will not bring him back.'],
#  ['00:48:41', " You didn't get him killed."],
#  ['00:48:43', ' Neither did you.'],
#  ['00:48:46', "Don't make it personal."],
#  ['00:48:50', 'Never.'],
#  ['00:48:52', 'Bond.'],
#  ['00:48:55', 'Come back alive.'],
#  ['00:48:59', 'Good morning, General Ourumov.'],
#  ['00:49:02', 'Defense Minister Mishkin, gentlemen.'],
#  ['00:49:05', 'Please deliver your report.'],
#  ['00:49:07', 'As this Council is aware,'],
#  ['00:49:10', '72 hours ago... a secret weapon system codenamed'],
#  ['00:49:13', 'GoldenEye was detonated over Severnaya.'],
#  ['00:49:15', 'As head of Space Division...'],
#  ['00:49:17', 'I personally undertook the investigation.'],
#  ['00:49:20',
#   'I have concluded this crime was committed by Siberian separatists... seeking to create political unrest.'],
#  ['00:49:26',
#   'Regrettably, the peaceful work... and muchneeded hard currency earnings of Severnaya... have been set back by several years.'],
#  ['00:49:28', 'Therefore,'],
#  ['00:49:30', 'I tender my resignation.'],
#  ['00:49:32',
#   'It seems the Council does not want your head, Arkady Grigorovich.'],
#  ['00:49:36',
#   'Merely your Ioyal assurance that there are no other GoldenEye satellites.'],
#  ['00:49:40', 'I can give you that assurance,'],
#  ['00:49:43', 'Defense Minister.'],
#  ['00:49:47', 'And what of the two missing'],
#  ['00:49:53', 'Severnaya technicians?'],
#  ['00:49:58', 'I was aware only of the one,'],
#  ['00:50:01', 'Boris Grishenko.'],
#  ['00:50:04', 'There was a girl also whose body was not among the dead.'],
#  ['00:50:08', 'Natalya Fyodorovna Simonova, a leveltwo programmer.'],
#  ['00:50:13', 'I will investigate immediately,'],
#  ['00:50:16', 'Defense Minister.'],
#  ['00:50:18', 'It would seem presumptuous,'],
#  ['00:50:20',
#   'General... to blame this incident on Siberian separatists... before the whereabouts of your own people are determined.'],
#  ['00:50:22', 'Do you agree?'],
#  ['00:50:26', 'Yes, Defense Minister.'],
#  ['00:50:29', 'Thank you for bringing it to my attention.'],
#  ['00:50:36', 'That will be all.'],
#  ['00:50:38', 'Morning, Q.'],
#  ['00:50:40', 'Sorry about the leg. Skiing?'],
#  ['00:50:43', 'Hunting!'],
#  ['00:50:49', 'Right. Now pay attention, 007.'],
#  ['00:50:53', 'First, your new car, BMW.'],
#  ['00:51:21',
#   'Agile, five forward gears, allpoints radar... selfdestruct system... and naturally, all the usual refinements.'],
#  ['00:51:23', "Now, this I'm particularly proud of."],
#  ['00:51:26', 'Behind the headlights,'],
#  ['00:51:28', 'Stinger missiles.'],
#  ['00:51:31',
#   'Excellent. Just the thing for unwinding after a rough day at the office.'],
#  ['00:51:34',
#   'Need I remind you, 007... that you have a licence to kill... not to break the traffic laws.'],
#  ['00:51:51', " I wouldn't think of it."],
#  ['00:51:56', ' Good.'],
#  ['00:51:58', "Right. Let's get on to more practical matters."],
#  ['00:52:00', 'A typical leather belt.'],
#  ['00:52:02', 'Male, size 34, buckle notch.'],
#  ['00:52:04', ' Have you finished?'],
#  ['00:52:08', ' Yes.'],
#  ['00:52:09', 'Good. A typical leather belt.'],
#  ['00:52:23', "Q, I'm familiar with that device."],
#  ['00:52:26', 'Not one with a 75foot rappelling cord built into the buckle.'],
#  ['00:52:29',
#   'Fire, and out shoots a piton... followed by a hightensile wire designed to support your weight.'],
#  ['00:52:31', 'I see. And what if I need additional support?'],
#  ['00:52:33', "It's tested for one, 007."],
#  ['00:52:36', 'Flight 878 to St. Petersburg.'],
#  ['00:52:54', 'Xray document scanner.'],
#  ['00:52:57', 'A pen.'],
#  ['00:53:00', 'This is a Class Four grenade.'],
#  ['00:53:04', 'Three clicks arms the foursecond fuse.'],
#  ['00:53:09', 'Another three disarms it.'],
#  ['00:53:12', 'How long did you say the fuse was?'],
#  ['00:53:16', 'Oh, grow up, 007!'],
#  ['00:53:20', 'They always said the pen was mightier than the sword.'],
#  ['00:53:23', 'Thanks to me, they were right.'],
#  ['00:53:27', "Look, let's ask Freddie here to demonstrate for us."],
#  ['00:53:30', 'Here we are.'],
#  ['00:53:37', 'Sorry about this, Fred.'],
#  ['00:53:40', 'One... two... three.'],
#  ['00:53:43', "Don't say it."],
#  ['00:53:46', "The writing's on the wall?"],
#  ['00:54:12', 'Along with the rest of him.'],
#  ['00:54:15', 'Now, 007, do please try and return some of...'],
#  ['00:54:17',
#   'Do please try and return some of this equipment in pristine order.'],
#  ['00:54:20', "Don't touch that!"],
#  ['00:54:23', "It's my lunch."],
#  ['00:54:25', 'In London,'],
#  ['00:54:29', "April's a spring month."],
#  ['00:54:31', 'Oh, yeah?'],
#  ['00:54:33', 'And what are you, the weatherman?'],
#  ['00:54:51',
#   'For crying out loud, another stiffassed Brit... with your secret codes and your passwords.'],
#  ['00:55:07',
#   'One of these days you guys are going to learn just to drop it.'],
#  ['00:55:09', "Come on, my car's over there."],
#  ['00:55:24', ' After you.'],
#  ['00:55:26', ' Thank you.'],
#  ['00:55:30', 'Like you said, drop it.'],
#  ['00:55:33', 'In London,'],
#  ['00:55:35',
#   "April's a spring month... whereas in St. Petersburg we're freezing our butts off!"],
#  ['00:55:37', 'Now, is that close enough for government work?'],
#  ['00:55:39', 'No. Show me the rose.'],
#  ['00:55:47', 'Please, no.'],
#  ['00:55:50', 'All right, all right, all right!'],
#  ['00:55:52', ' Muffy?'],
#  ['00:55:55', ' Third wife.'],
#  ['00:55:58', ' Jack Wade, CIA.'],
#  ['00:56:53', ' James Bond, stiffassed Brit.'],
#  ['00:56:55', " That's a nice move."],
#  ['00:57:03', ' Nice car.'],
#  ['00:57:07', "This baby hasn't let me down yet."],
#  ['00:57:15', "She's an ugly little bitch, but she gets you there."],
#  ['00:57:19', 'Hey, Bond, you do any gardening?'],
#  ['00:57:21', 'Hand me that wrench, Jimmy?'],
#  ['00:57:24', ' What do you know about Janus?'],
#  ['00:57:26', ' Zilch. Zipsky.'],
#  ['00:57:51', "No one's ever seen him."],
#  ['00:57:55', "But the man's connected up the kazoo."],
#  ['00:57:59', 'KGB, military.'],
#  ['00:58:02', 'Screwdriver.'],
#  ['00:58:06',
#   "Rumor has it, he lives on one of those old Soviet missile trains... that armored stuff they ran around the country so we couldn't target them."],
#  ['00:58:09', 'Want to hand me that hammer, Jimbo?'],
#  ['00:58:12', 'No, the bigger one.'],
#  ['00:58:18', 'The sledge.'],
#  ['00:58:22',
#   "Anyways, to tell the truth, you don't find this guy. He finds you."],
#  ['00:58:25', "Hell, it's all Russian Mafia."],
#  ['00:58:32',
#   'The best thing I can do is point you in the direction of his competition.'],
#  ['00:58:34', ' Who is the competition?'],
#  ['00:58:37', ' An exKGB guy.'],
#  ['00:58:39', "A tough mother. Got a limp on his right leg. Name's Zukovsky."],
#  ['00:58:43', ' Valentin Dimitreveych Zukovsky?'],
#  ['00:58:44', ' Yeah. You know him?'],
#  ['00:58:49', 'I gave him the limp.'],
#  ['00:58:54', 'Yes?'],
#  ['00:58:56', 'Are these all you have?'],
#  ['00:59:00', 'How many do you want?'],
#  ['00:59:03', 'Twentyfour for the American school, eleven for the Swedish.'],
#  ['00:59:05', 'IBM compatible with 500 meg. Hard drives...'],
#  ['00:59:07', 'CD ROM and 14.4 modems.'],
#  ['00:59:11', ' Will you pay dollars?'],
#  ['00:59:14', ' Of course.'],
#  ['00:59:18', 'If madame would require a demonstration, I could...'],
#  ['00:59:21',
#   'Madame requires one demonstration model and a quiet place to test it.'],
#  ['00:59:24', 'Natalya.'],
#  ['00:59:30', 'Is everything satisfactory?'],
#  ['00:59:34', 'Everything except the interruption.'],
#  ['00:59:38', 'Now let me get you straight, Jimmy.'],
#  ['00:59:41',
#   'You shot him in the leg, you stole his car, you took his girl.'],
#  ['00:59:43', 'And now you want Valentin Zukovsky to set you up with Janus?'],
#  ['00:59:46', 'Yes.'],
#  ['00:59:49', 'Well, what are you going to do?'],
#  ['00:59:52', 'Appeal to his heart?'],
#  ['00:59:55', 'No, his wallet.'],
#  ['00:59:59', 'Oh, that might work.'],
#  ['01:00:01', 'Okay, show time.'],
#  ['01:00:04', 'Valentin operates out of building number 23 there.'],
#  ['01:00:06', 'Are you sure you want to do this?'],
#  ['01:00:07',
#   'Last guy who dropped in uninvited went home airfreight... in very small boxes.'],
#  ['01:00:10', 'Make sure they send me home firstclass.'],
#  ['01:00:12', "Natalya, it's me!"],
#  ['01:00:15', "It's Boris!"],
#  ['01:00:19', "It's Boris! It's Boris!"],
#  ['01:00:22', 'Hello.'],
#  ['01:00:26', 'Another morning shot to hell.'],
#  ['01:00:28', 'Free market economy.'],
#  ['01:00:32', 'I swear it will be the end of me.'],
#  ['01:00:36', 'Walther PPK,'],
#  ['01:00:38', '7.65 millimeter.'],
#  ['01:00:42', 'Only three men I know use such a gun.'],
#  ['01:00:45', "I believe I've killed two of them."],
#  ['01:00:48', 'Lucky me.'],
#  ['01:00:52', 'I think not.'],
#  ['01:00:56', 'James Bond.'],
#  ['01:00:58', 'Charming, sophisticated secret agent.'],
#  ['01:01:03', 'Shaken but not stirred.'],
#  ['01:02:03',
#   "I see you haven't lost your delicate sense of humor, Valentin, huh?"],
#  ['01:02:06', 'Or your need for an audience.'],
#  ['01:02:15', "Who's strangling the cat?"],
#  ['01:02:17', 'Strangling a cat?'],
#  ['01:02:42', 'That is Irina, my mistress.'],
#  ['01:03:03', 'A very talented girl.'],
#  ['01:03:13', 'Irina! Take a hike!'],
#  ['01:03:15',
#   'So, Mr. Bond... what is it that brings you to my neighborhood, hmm?'],
#  ['01:03:22',
#   'Still working for Ml6... or have you decided to join the 21st century?'],
#  ['01:03:25', 'I hear the new M is a lady.'],
#  ['01:03:28', 'I want you to do me a favor.'],
#  ['01:03:45', 'He wants me to do him a favor!'],
#  ['01:03:49',
#   'My knee aches... every single day, twice as bad when it is cold.'],
#  ['01:03:54',
#   'Have you any idea how long the winter lasts in this country, hmm?'],
#  ['01:03:57', 'Tell him, Dimitri!'],
#  ['01:03:59', ' Well, it depends...'],
#  ['01:04:03', ' Silence!'],
#  ['01:05:15', 'For an exKGB agent, you surprise me, Valentin.'],
#  ['01:05:38',
#   "Someone of your stature must've realized the skill was not to hit your knee... but to... miss the rest of you."],
#  ['01:05:41', 'So why did you not kill me?'],
#  ['01:05:46', 'Call it professional courtesy.'],
#  ['01:05:49', 'Then I should extend you the same courtesy.'],
#  ['01:05:51', "Kirov's funeral parlor,"],
#  ['01:05:55', '4:00 this afternoon.'],
#  ['01:05:59', 'Two hundred pounds of C4 explosives hidden in a casket.'],
#  ['01:06:01',
#   "Your man drives the hearse in, the money's exchanged... their man drives the hearse out."],
#  ['01:06:05', 'Their man will be arrested with the explosives.'],
#  ['01:06:08', 'Your man will make a miraculous escape with the money.'],
#  ['01:06:11', 'Your money.'],
#  ['01:06:15', 'And what do I owe for this accommodation?'],
#  ['01:06:18', 'I want you to set me up... with Janus.'],
#  ['01:06:21', 'What has he done to deserve you?'],
#  ['01:06:24', ' Stole a helicopter.'],
#  ['01:06:30', ' I have six.'],
#  ['01:06:33', 'Three. None that fly.'],
#  ['01:06:37', "Who's counting?"],
#  ['01:06:40', 'These are not just criminals,'],
#  ['01:06:43', "Valentin, they're traitors."],
#  ['01:06:47', 'They used the chopper to steal a nuclear weapon.'],
#  ['01:06:50', 'Killed a lot of innocent Russians doing it.'],
#  ['01:06:54', ' What do you expect from a Cossack?'],
#  ['01:06:58', ' Who?'],
#  ['01:07:04',
#   "This Janus, I've never met the man, but I know he's a Lienz Cossack."],
#  ['01:07:07',
#   'Group that worked for the Nazis against the Russians, Second World War.'],
#  ['01:07:10', 'You know your history, Mr. Bond.'],
#  ['01:07:13',
#   "At the end of the war... the Lienz Cossacks surrendered to the British in Austria... believing they'd join your government and wage war against the communists."],
#  ['01:07:16',
#   'But, the British betrayed them... sent them promptly back to Stalin who promptly had them all shot... women, children, families.'],
#  ['01:07:19', 'Not exactly our finest hour.'],
#  ['01:07:21', 'Still, ruthless people.'],
#  ['01:07:25', 'They got what they deserved.'],
#  ['01:07:28', 'I want you to set me up with Janus.'],
#  ['01:07:30', "Tell him I'm asking about the chopper."],
#  ['01:07:36', "You're going to meet me tonight at the Grand Hotel Europe."],
#  ['01:07:38', 'And then, you and I are even and he owes me one?'],
#  ['01:07:41', 'Precisely.'],
#  ['01:07:43', "You don't need the gun,"],
#  ['01:07:50', 'Commander.'],
#  ['01:08:07', "That depends on your definition of 'safe sex. '"],
#  ['01:08:09', "That's close enough."],
#  ['01:08:11', 'Not for what I have in mind.'],
#  ['01:08:14', 'Oh, you think you can hurt me?'],
#  ['01:08:16', 'You think you can break me?'],
#  ['01:08:18', 'Yes! Yes!'],
#  ['01:08:20', 'Yes!'],
#  ['01:08:23', 'No, no, no.'],
#  ['01:08:28', 'No more foreplay.'],
#  ['01:08:30', 'Take me to Janus.'],
#  ['01:09:49', ' This is it?'],
#  ['01:09:54', ' Yes.'],
#  ['01:09:56', 'Well, I must say,'],
#  ['01:10:06', "I've had a lovely evening. You?"],
#  ['01:10:50', 'Well, once again, the pleasure was all yours.'],
#  ['01:10:53', "You'll understand if I don't call."],
#  ['01:10:56', "I won't lose sleep over it."],
#  ['01:10:58', 'Sweet dreams.'],
#  ['01:11:00', 'Hello, James.'],
#  ['01:11:03', ' Alec?'],
#  ['01:11:05', ' Back from the dead.'],
#  ['01:11:08', 'No longer just an anonymous star on the memorial wall at Ml6.'],
#  ['01:11:12', "What's the matter, James?"],
#  ['01:11:17', 'No glib remark?'],
#  ['01:11:19', 'No pithy comeback?'],
#  ['01:11:22', 'Why?'],
#  ['01:11:35', 'Hilarious question, particularly from you.'],
#  ['01:11:39', 'Did you ever ask why?'],
#  ['01:11:42',
#   'Why we toppled all those dictators, undermined all those regimes?'],
#  ['01:11:45', "Only to come home: 'Well done, good job."],
#  ['01:11:48', 'But sorry, old boy.'],
#  ['01:11:50', "Everything you risked your life and limb for has changed. '"],
#  ['01:11:53', ' It was the job we were chosen for.'],
#  ['01:11:55', " Of course you'd say that."],
#  ['01:11:59', 'James Bond,'],
#  ['01:12:04',
#   "Her Majesty's Ioyal terrier... defender of the socalled 'faith. '"],
#  ['01:12:08', 'Oh, please, James, put it away.'],
#  ['01:12:11',
#   "It's insulting to think I haven't anticipated your every move."],
#  ['01:12:16', 'Yes.'],
#  ['01:12:19', ' I trusted you, Alec.'],
#  ['01:12:26', ' Trust?'],
#  ['01:12:29', 'What a quaint idea.'],
#  ['01:12:32',
#   'How did the Ml6 screening miss that your parents were Lienz Cossacks?'],
#  ['01:12:34', 'Once again, your faith is misplaced.'],
#  ['01:12:38', 'They knew.'],
#  ['01:12:42', "We're both orphans, James."],
#  ['01:12:45',
#   "But where your parents had the luxury of dying in a climbing accident... mine survived the British betrayal and Stalin's execution squads."],
#  ['01:12:47',
#   "But my father couldn't let himself, or my mother, live with the shame of it."],
#  ['01:12:51', 'Ml6 figured I was too young to remember.'],
#  ['01:12:53',
#   "And in one of life's little ironies... the son went to work for the government whose betrayal... caused the father to kill himself and his wife."],
#  ['01:12:56', 'Hence, Janus.'],
#  ['01:12:58', 'The twofaced Roman god come to life.'],
#  ['01:13:02',
#   "It wasn't God who gave me this face, it was you... setting the timers for three minutes instead of six."],
#  ['01:13:09', 'Am I supposed to feel sorry for you?'],
#  ['01:13:13', "No. You're supposed to die for me."],
#  ['01:13:16', 'Oh, by the way...'],
#  ['01:13:19',
#   'I did think of asking you to join my little scheme... but somehow I knew...'],
#  ['01:13:25', "007's Ioyalty was always to the mission, never to his friend."],
#  ['01:13:28', 'Closing time, James.'],
#  ['01:13:33', 'Last call.'],
#  ['01:13:36', 'For England, James.'],
#  ['01:13:39', 'Wake up!'],
#  ['01:13:44', 'Mister!'],
#  ['01:13:46', 'Wake up, please!'],
#  ['01:13:51', ' Wake up!'],
#  ['01:13:55', " I'm here."],
#  ['01:13:57', " I'm here!"],
#  ['01:13:59', ' Hurry!'],
#  ['01:14:02', 'Hurry up! Come out!'],
#  ['01:14:09', 'Pull yourself together!'],
#  ['01:14:13', "We're going to die!"],
#  ['01:14:20', 'Do something!'],
#  ['01:14:35', 'Get us out of here!'],
#  ['01:15:15', "I'm a little tied up..."],
#  ['01:15:21', 'Never mind.'],
#  ['01:16:12', "The things that we do for 'frequent flyer' mileage."],
#  ['01:16:15', 'Here, let me help you.'],
#  ['01:16:52', "That's it, mind your head."],
#  ['01:17:22', 'Let me go!'],
#  ['01:17:43', 'Who are you?'],
#  ['01:17:51', "Listen, I'm on your side."],
#  ['01:18:50', "I'm here to help you."],
#  ['01:20:25', " I don't know anything."],
#  ['01:21:02', " I don't believe you."],
#  ['01:21:43', " I don't care what you believe."],
#  ['01:22:35', ' Look!'],
#  ['01:22:38', 'They might be back for us any minute.'],
#  ['01:22:40',
#   'You either take your chances with me... or your fellow countrymen who killed everyone at Severnaya.'],
#  ['01:22:44', "I've never been to Severnaya."],
#  ['01:22:47', 'Your watch has.'],
#  ['01:22:48', 'Frozen by the GoldenEye blast.'],
#  ['01:22:54',
#   "And I'm willing to bet you're the one who climbed up the dish to get out."],
#  ['01:23:13', ' Who are you?'],
#  ['01:23:18', ' I work for the British government.'],
#  ['01:23:24', 'And the more you tell me, the more I can help you.'],
#  ['01:23:36', " But I don't know anything!"],
#  ['01:23:44', " Then let's start with what you do know."],
#  ['01:23:55', 'My name is Natalya Simonova.'],
#  ['01:24:03', 'I was a systems programmer at Severnaya facility until...'],
#  ['01:24:04', 'Go on.'],
#  ['01:24:06', ' Until they killed everyone.'],
#  ['01:24:09', ' Who? Alec Trevelyan?'],
#  ['01:24:12', "No. I don't know who that is."],
#  ['01:25:16', 'Who was the insider?'],
#  ['01:25:18', 'Who was the traitor?'],
#  ['01:25:20', 'Boris.'],
#  ['01:25:23', 'Boris Grishenko.'],
#  ['01:25:28', ' KGB or military?'],
#  ['01:25:33', ' Computer programmer.'],
#  ['01:25:36', ' There was no one else?'],
#  ['01:25:39', ' No.'],
#  ['01:25:40', "They're going to kill me, aren't they?"],
#  ['01:25:45', 'Trust me.'],
#  ['01:25:49', 'Trust you?'],
#  ['01:25:51', "I don't even know your name."],
#  ['01:25:54', 'Good morning, Mr. Bond.'],
#  ['01:26:04', 'Sit.'],
#  ['01:26:07', "I'm Defense Minister"],
#  ['01:26:10', 'Dimitri Mishkin.'],
#  ['01:26:16', 'So, by what means shall we execute you, Commander Bond?'],
#  ['01:26:22', 'What, no small talk?'],
#  ['01:26:25', 'No chitchat?'],
#  ['01:26:28', "That's the trouble with the world today."],
#  ['01:26:31',
#   "No one takes the time to do a sinister interrogation anymore. It's a lost art."],
#  ['01:26:36', "Your sense of humor doesn't slay me,"],
#  ['01:26:39', "Commander. I'm sorry."],
#  ['01:26:45', ' Where is the GoldenEye?'],
#  ['01:26:48', ' I assumed you had it.'],
#  ['01:26:52',
#   'I have an English spy, a Severnaya programmer and the helicopter they took.'],
#  ['01:26:54',
#   "That's what some traitor in your government wanted it to look like."],
#  ['01:27:00', ' Who was behind the attack on Severnaya?'],
#  ['01:27:12', ' Who had the authorization codes?'],
#  ['01:27:14',
#   'Russia may have changed, but the penalty for terrorism is still death!'],
#  ['01:27:21', " And what's the penalty for treason?"],
#  ['01:27:25', ' Stop it, both of you! Stop it!'],
#  ['01:27:27', "You're like boys with toys."],
#  ['01:27:33', 'It was Ourumov.'],
#  ['01:27:36', 'General Ourumov set off the weapon.'],
#  ['01:27:54', 'I saw him do it.'],
#  ['01:27:56', 'Are you certain it was Ourumov?'],
#  ['01:28:01', 'Yes. He killed everyone and stole the GoldenEye.'],
#  ['01:28:05', 'And why would he do that?'],
#  ['01:28:41', 'There is another satellite.'],
#  ['01:28:42', 'Another GoldenEye?'],
#  ['01:28:44', 'Thank you, Miss Simonova.'],
#  ['01:28:47',
#   'You were saying something about the lost art of interrogation, Mr. Bond?'],
#  ['01:28:54', 'Defense Minister, I must protest!'],
#  ['01:28:56', 'This is my investigation.'],
#  ['01:28:59', 'You are out of order.'],
#  ['01:29:00', "From what I am hearing, it is you who's out of order!"],
#  ['01:29:02', ' I have seen this gun before.'],
#  ['01:29:04', ' Put it down.'],
#  ['01:29:11', ' In the hand of our enemy.'],
#  ['01:29:13', ' Put it down, General!'],
#  ['01:29:17', 'Do you even know who the enemy is, Dimitri?'],
#  ['01:29:37', ' Do you?'],
#  ['01:29:40', ' Guard!'],
#  ['01:29:44',
#   'Defense Minister Dimitri Mishkin... murdered by a British agent,'],
#  ['01:29:49', 'James Bond.'],
#  ['01:29:54', 'Himself shot while trying to escape. Guards!'],
#  ['01:29:55', 'Come on!'],
#  ['01:30:00', "They're in the archives!"],
#  ['01:30:05', 'Down!'],
#  ['01:30:09', 'Spread out!'],
#  ['01:30:12', 'Cover the other side!'],
#  ['01:30:19', 'Trust me.'],
#  ['01:30:21', 'Go now!'],
#  ['01:30:24', 'Faster!'],
#  ['01:30:48', 'Damn it!'],
#  ['01:30:52', 'Down the alley!'],
#  ['01:30:54', 'Use the bumper!'],
#  ['01:31:08', "That's what it's for!"],
#  ['01:31:35', 'What was that?'],
#  ['01:31:37', 'Go left!'],
#  ['01:31:40', 'Get out!'],
#  ['01:31:42',
#   "Either you've brought me the perfect gift, General Ourumov... or you've made me a very unhappy man."],
#  ['01:31:45', 'Mishkin got to them before I could.'],
#  ['01:31:47', 'Bond is alive?'],
#  ['01:31:50', 'He escaped.'],
#  ['01:31:52', 'Good for Bond.'],
#  ['01:31:54', 'Bad for you.'],
#  ['01:31:57', 'Take a seat, my dear.'],
#  ['01:31:59', 'You know, James and I shared everything.'],
#  ['01:32:02', 'Absolutely everything.'],
#  ['01:32:04', 'To the victor go the spoils.'],
#  ['01:32:08', "You'll like it where we're going."],
#  ['01:32:10', 'You may even learn to like me.'],
#  ['01:32:12', 'Stay with her.'],
#  ['01:32:17', 'Bond.'],
#  ['01:32:19', 'Only Bond.'],
#  ['01:32:23', "He's going to derail us."],
#  ['01:32:26', 'Full speed!'],
#  ['01:32:30', 'Full speed! Ram him!'],
#  ['01:32:31', "Why can't you just be a good boy and die?"],
#  ['01:32:36', 'You first.'],
#  ['01:32:38', 'You... second.'],
#  ['01:32:40', 'Up!'],
#  ['01:32:44', 'Situation analysis: hopeless.'],
#  ['01:32:46', 'You have no backup, no escape route.'],
#  ['01:32:53', 'And I have the only bargaining chip.'],
#  ['01:32:56', 'Where is she?'],
#  ['01:32:59', 'Oh, yes.'],
#  ['01:34:06', 'Your fatal weakness.'],
#  ['01:34:10', 'Ourumov, bring her in.'],
#  ['01:34:15', 'Lovely girl.'],
#  ['01:34:18', 'Tastes like... like strawberries.'],
#  ['01:34:21', " I wouldn't know."],
#  ['01:34:23', ' I would.'],
#  ['01:34:25', 'So, back where we started, James.'],
#  ['01:34:29', 'Your friend or the mission.'],
#  ['01:34:32', 'Drop the gun.'],
#  ['01:34:34', "I'll let her live."],
#  ['01:34:39', 'Ourumov, what has this'],
#  ['01:34:43', 'Cossack promised you?'],
#  ['01:34:45', "You knew, didn't you?"],
#  ['01:35:24', "He's a Lienz Cossack."],
#  ['01:35:28', " It's in the past."],
#  ['01:35:36', " He'll betray you!"],
#  ['01:35:39', ' Just like everyone else.'],
#  ['01:35:43', ' Is this true?'],
#  ['01:35:47',
#   "What's true is that in 48 hours you and I will have more money than God."],
#  ['01:35:49',
#   'And Mr. Bond here will have a small memorial service... with only Moneypenny and a few tearful restaurateurs in attendance.'],
#  ['01:35:57', "So, what's the choice, James?"],
#  ['01:36:30', 'Two targets.'],
#  ['01:36:35', 'Time enough for one shot.'],
#  ['01:37:00', 'The girl, or the mission?'],
#  ['01:37:04', 'Kill her.'],
#  ['01:37:18', 'She means nothing to me.'],
#  ['01:38:17', 'See you in hell, James.'],
#  ['01:39:16', 'Oneinch armor plating.'],
#  ['01:39:39', "I'm fine, thank you very much!"],
#  ['01:40:14', ' Boris, yes!'],
#  ['01:40:26', ' What are you doing?'],
#  ['01:40:29', 'Boris is online, backing up his files.'],
#  ['01:40:31',
#   "If I can spike him, I might be able to find out where they're going."],
#  ['01:40:35', "But don't stand there!"],
#  ['01:41:06', 'Get us out of here!'],
#  ['01:41:18', 'Yes, sir.'],
#  ['01:41:34', 'Good luck with the floor, James.'],
#  ['01:41:38',
#   'I set the timers for six minutes... the same six minutes you gave me.'],
#  ['01:42:42', 'It was the least'],
#  ['01:42:50', 'I could do for a friend.'],
#  ['01:42:52', ' What does that mean?'],
#  ['01:42:56', " We've got three minutes."],
#  ['01:43:12', 'What else do you call your butt?'],
#  ['01:43:14', ' What?'],
#  ['01:43:48', " It's Boris' password."],
#  ['01:43:53',
#   "He plays word games: 'What I sit on, but I don't take it with me. '"],
#  ['01:43:56', ' Chair.'],
#  ['01:44:27', ' Like I said.'],
#  ['01:44:47', 'Thirty seconds.'],
#  ['01:44:49', "He's not in Russia, Germany,"],
#  ['01:46:13', 'Paris, London, Madrid.'],
#  ['01:46:16', 'Twentyfive seconds.'],
#  ['01:46:19', 'New York, Toronto, Chicago,'],
#  ['01:46:28', 'San Francisco.'],
#  ['01:46:31', 'Twenty seconds!'],
#  ['01:46:33', 'Mexico City, Rio, Miami.'],
#  ['01:46:40', ' Come on!'],
#  ['01:46:42', ' Wait!'],
#  ['01:47:00', "He's in Cuba, Havana. No."],
#  ['01:47:03', 'Now!'],
#  ['01:47:06', 'Do you destroy every vehicle you get into?'],
#  ['01:47:09', 'Standard operating procedure.'],
#  ['01:47:11', "'Boys with toys. '"],
#  ['01:47:15',
#   'Maybe I should take care of the transportation for our trip to Cuba.'],
#  ['01:47:18', 'Our trip?'],
#  ['01:47:22', 'Do you know how to disarm the weapon?'],
#  ['01:47:25',
#   "I suppose that depends on what kind of weapon you're talking about disarming."],
#  ['01:47:36', 'So, tell me.'],
#  ['01:47:39', 'Are there any other standard operating procedures...'],
#  ['01:47:41', 'I should be aware of, Commander?'],
#  ['01:47:44', 'Thousands.'],
#  ['01:47:48', 'But I only pay them... lip service.'],
#  ['01:47:51', 'My whole life, I dreamed about coming to the Caribbean.'],
#  ['01:47:54', "It's so beautiful."],
#  ['01:47:58', 'Not another human being in sight.'],
#  ['01:48:00', 'What is it with you and moving vehicles?'],
#  ['01:48:05', 'Yo, Jimbo!'],
#  ['01:48:08', "Brought a little gift from old what'shisname, uh, T, Z...?"],
#  ['01:48:12', ' Q.'],
#  ['01:48:17', ' Yeah.'],
#  ['01:48:20', ' What are you doing here, Wade?'],
#  ['01:48:25', ' Banyan trees.'],
#  ['01:48:28', 'I am not here.'],
#  ['01:48:33',
#   'The CIA has no knowledge, no involvement, absolutely nothing to do... with your insertion into Cuba, if you catch my drift.'],
#  ['01:49:09', 'Yes, I do, perfectly.'],
#  ['01:49:13', 'Borrowed the plane from a friend of mine in the DEA.'],
#  ['01:49:15', 'Now, the Coast Guard and the FAA are both in the loop.'],
#  ['01:49:20', "You're cleared on our radar for 0600 hours."],
#  ['01:49:22', "Here's the latest SatInt from Langley."],
#  ['01:49:27', ' Stay below 600 feet.'],
#  ['01:49:30', ' 500 feet.'],
#  ['01:49:37', " Who's that?"],
#  ['01:49:56', ' Natalya Siminova.'],
#  ['01:49:58', 'Natalya Simonova.'],
#  ['01:50:04', 'Russian Minister of Transportation.'],
#  ['01:50:08', 'Did you check her out?'],
#  ['01:50:11', ' Head to toe.'],
#  ['01:50:16', ' Right.'],
#  ['01:50:21',
#   "So, you're looking for a dish the size of a football field, huh?"],
#  ['01:50:23',
#   "Doesn't exist. You can't light a cigar in Cuba without us seeing it."],
#  ['01:50:53', "I know it's there."],
#  ['01:50:56',
#   "It's a duplicate of Severnaya, like your secret transmitters in New Zealand."],
#  ['01:51:15', "I've never been to New Zealand."],
#  ['01:51:17', "How'd she know about that?"],
#  ['01:51:20', 'What if I need backup?'],
#  ['01:51:22', 'Get on the radio.'],
#  ['01:51:53', "I'll send in the Marines."],
#  ['01:51:57', 'Anyway, hang a left at the end of the runway.'],
#  ['01:51:59', " Cuba's 80 miles on your right."],
#  ['01:52:16', ' Yo, Wade.'],
#  ['01:52:18', "Just one thing: Don't push any of the buttons on that car."],
#  ['01:52:21', ' I was going to go bombing around in it.'],
#  ['01:53:42', ' Exactly.'],
#  ['01:55:50', 'Yo, James, I got faith.'],
#  ['01:56:11', "But be careful. He knows you're coming."],
#  ['01:56:14', 'He was your friend, Trevelyan?'],
#  ['01:57:14', "And now he's your enemy and you will kill him."],
#  ['01:57:50', 'It is that simple?'],
#  ['01:57:52', 'In a word, yes.'],
#  ['01:57:55', 'Unless he kills you first.'],
#  ['01:59:12', ' Natalya...'],
#  ['01:59:38', " You think I'm impressed?"],
#  ['01:59:41',
#   'All of you with your guns, your killing, your death. For what?'],
#  ['01:59:46', 'So you can be a hero?'],
#  ['01:59:57', ' All the heroes I know are dead.'],
#  ['02:00:00', ' Natalya, listen to me.'],
#  ['02:00:05', 'How can you act like this?'],
#  ['02:00:15', 'How can you be so cold?'],
#  ['02:00:21', "It's what keeps me alive."],
#  ['02:00:25', 'No.'],
#  ['02:00:37', "It's what keeps you alone."],
#  ['02:00:40', 'James?'],
#  ['02:00:43', 'Yes?'],
#  ['02:00:45',
#   'On the train... when you told him to kill me and I meant nothing to you... did you mean it?'],
#  ['02:00:48', 'Yes.'],
#  ['02:00:53', 'Basic rule: always call their bluff.']]

# %%
bond_srts = ['GoldenEye', 'Goldfinger']
bond_dfs = []

for srt in bond_srts:
    srt_test = f'Subtitles/{srt}.en.srt'
    encoding = 'utf-8' 
    temp = srt_to_txt(srt_test, encoding)[1:] #ignore first advertisement 
    bond_dfs.append(temp)    

for title, df in zip(bond_srts, bond_dfs):
    df = pd.DataFrame(df, columns=['Timestamp', 'Dialogue'])
    df['Sentiment'] = df.Dialogue.apply(lambda x: get_sentiment(x))

    # Set rolling means for sentiment
    df['Rol_Sentiment'] = df['Sentiment'].rolling(25, min_periods=5).mean()
    df['Exp_Sentiment'] = df['Sentiment'].expanding(5).mean()
    df.fillna(method='bfill', inplace=True)

    df.index = (pd.to_timedelta(df['Timestamp'].str.strip()))
#     print(df.head(5))
    
    #Plotting
    plt.figure(figsize=(12,8))
    
    plt.plot(df.Rol_Sentiment)
    plt.plot(df.Exp_Sentiment)
    plt.title(f'{title}')
    
    g = sns.boxenplot(y=list(df.Sentiment), data=df, palette='Wistia')

    plt.axhline(y=0.0, color='r', linestyle=':', linewidth=0.5)
    plt.ylim(top=1, bottom=-1)
    
plt.show();

# %%
df
# Out:
#           Timestamp                                           Dialogue  \
# Timestamp
# 00:03:03   00:03:03                                   Congratulations.
# 00:03:06   00:03:06                                         Thank you.
# 00:03:08   00:03:08  Mr Romales and his friends will be out of busi...
# 00:03:14   00:03:14  He won't be using heroinflavoured bananas to f...
# 00:03:18   00:03:18  Don't go back to your hotel, ser. They'll be w...
# 00:03:22   00:03:22               There's a plane to Miami in an hour.
# 00:03:45   00:03:45   I'll be on it, but first I have some unfinish...
# 00:03:47   00:03:47                                        Forgive me.
# 00:03:49   00:03:49                 Why do you always wear that thing?
# 00:03:52   00:03:52               I have a slight inferiority complex.
# 00:04:49   00:04:49                                       Where was I?
# 00:04:55   00:04:55                                          Shocking!
# 00:05:21   00:05:21                               Positively shocking.
# 00:05:26   00:05:26                                        Goldfinger.
# 00:05:28   00:05:28                                      He's the man.
# 00:05:33   00:05:33                      The man with the Midas touch.
# 00:05:38   00:05:38                                  A spider's touch.
# 00:05:45   00:05:45                                Such a cold finger.
# 00:05:47   00:05:47                                       Beckons you.
# 00:05:52   00:05:52                           To enter his web of sin.
# 00:05:58   00:05:58                                   But don't go in.
# 00:06:03   00:06:03             Golden words he will pour in your ear.
# 00:06:07   00:06:07         But his lies can't disguise what you fear.
# 00:06:10   00:06:10                                 For a golden girl.
# 00:06:13   00:06:13                        Knows when he's kissed her.
# 00:06:16   00:06:16                            It's the kiss of death.
# 00:06:23   00:06:23                                From Mr Goldfinger.
# 00:06:24   00:06:24                                       Pretty girl.
# 00:06:30   00:06:30                      Beware of this heart of gold.
# 00:06:36   00:06:36                                This heart is cold.
# ...             ...                                                ...
# 01:44:56   01:44:56                                        Speed: 220.
# 01:44:58   01:44:58                              Wind check: Westerly.
# 01:45:01   01:45:01  Champagne leader to Champagne section. Commenc...
# 01:45:04   01:45:04                           Ready for Rockabye Baby.
# 01:45:07   01:45:07                       Commence spray on countdown.
# 01:45:10   01:45:10                      Five, four, three, two, zero.
# 01:45:13   01:45:13  Champagne leader to Grand Slam task force leader.
# 01:45:18   01:45:18                                The baby is asleep.
# 01:45:29   01:45:29  I repeat, the baby is asleep. We're going home...
# 01:45:33   01:45:33                                               Out.
# 01:45:35   01:45:35                             Good morning, Mr Bond.
# 01:45:38   01:45:38        For once, you are exactly where I want you.
# 01:45:42   01:45:42                                   The bomb's here.
# 01:45:45   01:45:45                       Let's get moving, Brigadier.
# 01:45:47   01:45:47                              Right, Jack, move in.
# 01:45:50   01:45:50                         Move in, commando tactics.
# 01:45:52   01:45:52  Minimum offensive fire until I signal bomb has...
# 01:46:26   01:46:26  Minimum offensive fire until I signal bomb has...
# 01:46:28   01:46:28               Bomb disposal unit to accompany DOG.
# 01:46:33   01:46:33                                  Goodbye, Mr Bond.
# 01:46:39   01:46:39                    Mr Ling, it is merely timing...
# 01:46:42   01:46:42                  He's one of them, so is the girl.
# 01:46:46   01:46:46               I'll get her, you get the door open.
# 01:46:51   01:46:51                                     We're trapped!
# 01:47:40   01:47:40                The bomb... I'll take the fuse out.
# 01:47:43   01:47:43                                   Don't be a fool!
# 01:47:49   01:47:49                        You can be a hero, I'm not!
# 01:48:26   01:48:26                                            No, no!
# 01:48:29   01:48:29                              Keep going! Hurry up!
# 01:48:32   01:48:32                                     What kept you?
#
#            Sentiment  Rol_Sentiment  Exp_Sentiment
# Timestamp
# 00:03:03      0.5994       0.287460       0.287460
# 00:03:06      0.3612       0.287460       0.287460
# 00:03:08      0.4767       0.287460       0.287460
# 00:03:14      0.0000       0.287460       0.287460
# 00:03:18      0.0000       0.287460       0.287460
# 00:03:22      0.0000       0.239550       0.239550
# 00:03:45      0.0000       0.205329       0.205329
# 00:03:47      0.2732       0.213813       0.213813
# 00:03:49      0.0000       0.190056       0.190056
# 00:03:52     -0.2732       0.143730       0.143730
# 00:04:49      0.0000       0.130664       0.130664
# 00:04:55     -0.4574       0.081658       0.081658
# 00:05:21      0.1779       0.089062       0.089062
# 00:05:26      0.0000       0.082700       0.082700
# 00:05:28      0.0000       0.077187       0.077187
# 00:05:33      0.0000       0.072362       0.072362
# 00:05:38      0.0000       0.068106       0.068106
# 00:05:45      0.0000       0.064322       0.064322
# 00:05:47      0.0000       0.060937       0.060937
# 00:05:52     -0.5574       0.030020       0.030020
# 00:05:58      0.0000       0.028590       0.028590
# 00:06:03      0.0000       0.027291       0.027291
# 00:06:07     -0.7839      -0.007978      -0.007978
# 00:06:10      0.0000      -0.007646      -0.007646
# 00:06:13      0.3818       0.007932       0.007932
# 00:06:16      0.0772      -0.012956       0.010596
# 00:06:23      0.0000      -0.027404       0.010204
# 00:06:24      0.4939      -0.026716       0.027479
# 00:06:30      0.0000      -0.026716       0.026531
# 00:06:36      0.0000      -0.026716       0.025647
# ...              ...            ...            ...
# 01:44:56      0.0000       0.115388       0.078729
# 01:44:58      0.0000       0.115388       0.078631
# 01:45:01      0.5267       0.136456       0.079187
# 01:45:04      0.3612       0.126928       0.079537
# 01:45:07      0.0000       0.093160       0.079439
# 01:45:10      0.0000       0.114852       0.079340
# 01:45:13      0.3818       0.151776       0.079714
# 01:45:18      0.0000       0.140848       0.079616
# 01:45:29      0.0000       0.114904       0.079518
# 01:45:33      0.0000       0.114904       0.079420
# 01:45:35      0.4404       0.132520       0.079864
# 01:45:38      0.0772       0.135608       0.079860
# 01:45:42      0.0000       0.121160       0.079762
# 01:45:45      0.0000       0.133516       0.079665
# 01:45:47      0.0000       0.133516       0.079567
# 01:45:50      0.0000       0.133516       0.079470
# 01:45:52     -0.8225       0.100616       0.078368
# 01:46:26     -0.8225       0.070004       0.077270
# 01:46:28     -0.4939       0.054356       0.076574
# 01:46:33      0.0000       0.054356       0.076481
# 01:46:39      0.0000       0.054356       0.076388
# 01:46:42      0.0000       0.040756       0.076295
# 01:46:46      0.0000       0.027156       0.076203
# 01:46:51     -0.5707      -0.007512       0.075420
# 01:47:40      0.0000      -0.036892       0.075329
# 01:47:43      0.4015      -0.020832       0.075722
# 01:47:49      0.5983       0.003100       0.076353
# 01:48:26     -0.5707      -0.040796       0.075573
# 01:48:29      0.0000      -0.055244       0.075482
# 01:48:32      0.0000      -0.055244       0.075392
#
# [832 rows x 5 columns]
